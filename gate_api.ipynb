# %%
# %matplotlib notebook

# %%
from plotting import DrawBounds

# %%
# x = range(10)
# y = range(10)
fig, ax = plt.subplots()
af =  DrawBounds(ax=ax)
ax.set_xlim(0,1.)
ax.set_ylim(0,1.)
fig.canvas.mpl_connect('button_press_event', af)
plt.show()
# Out:
# <img src="data:image/png;base64,...">
